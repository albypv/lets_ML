# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv(r"C:\Users\pvalb\Desktop\python\HeartAttack.csv",na_values='?')
data.head()
# Out:
#    age  sex  cp  trestbps   chol  fbs  restecg  thalach  exang  oldpeak  \
# 0   28    1   2     130.0  132.0  0.0      2.0    185.0    0.0      0.0
# 1   29    1   2     120.0  243.0  0.0      0.0    160.0    0.0      0.0
# 2   29    1   2     140.0    NaN  0.0      0.0    170.0    0.0      0.0
# 3   30    0   1     170.0  237.0  0.0      1.0    170.0    0.0      0.0
# 4   31    0   2     100.0  219.0  0.0      1.0    150.0    0.0      0.0
#
#    slope  ca  thal  num
# 0    NaN NaN   NaN           0
# 1    NaN NaN   NaN           0
# 2    NaN NaN   NaN           0
# 3    NaN NaN   6.0           0
# 4    NaN NaN   NaN           0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 294 entries, 0 to 293
# Data columns (total 14 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   age         294 non-null    int64
#  1   sex         294 non-null    int64
#  2   cp          294 non-null    int64
#  3   trestbps    293 non-null    float64
#  4   chol        271 non-null    float64
#  5   fbs         286 non-null    float64
#  6   restecg     293 non-null    float64
#  7   thalach     293 non-null    float64
#  8   exang       293 non-null    float64
#  9   oldpeak     294 non-null    float64
#  10  slope       104 non-null    float64
#  11  ca          3 non-null      float64
#  12  thal        28 non-null     float64
#  13  num         294 non-null    int64
# dtypes: float64(10), int64(4)
# memory usage: 32.3 KB

# %%
data.isnull().sum()
# Out:
# age             0
# sex             0
# cp              0
# trestbps        1
# chol           23
# fbs             8
# restecg         1
# thalach         1
# exang           1
# oldpeak         0
# slope         190
# ca            291
# thal          266
# num             0
# dtype: int64

# %%
data1=data.drop(['slope','ca','thal'],axis=1)
data1
# Out:
#      age  sex  cp  trestbps   chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     28    1   2     130.0  132.0  0.0      2.0    185.0    0.0      0.0
# 1     29    1   2     120.0  243.0  0.0      0.0    160.0    0.0      0.0
# 2     29    1   2     140.0    NaN  0.0      0.0    170.0    0.0      0.0
# 3     30    0   1     170.0  237.0  0.0      1.0    170.0    0.0      0.0
# 4     31    0   2     100.0  219.0  0.0      1.0    150.0    0.0      0.0
# ..   ...  ...  ..       ...    ...  ...      ...      ...    ...      ...
# 289   52    1   4     160.0  331.0  0.0      0.0     94.0    1.0      2.5
# 290   54    0   3     130.0  294.0  0.0      1.0    100.0    1.0      0.0
# 291   56    1   4     155.0  342.0  1.0      0.0    150.0    1.0      3.0
# 292   58    0   2     180.0  393.0  0.0      0.0    110.0    1.0      1.0
# 293   65    1   4     130.0  275.0  0.0      1.0    115.0    1.0      1.0
#
#      num
# 0             0
# 1             0
# 2             0
# 3             0
# ...

# %%
data1=data1.dropna()
data1
# Out:
#      age  sex  cp  trestbps   chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     28    1   2     130.0  132.0  0.0      2.0    185.0    0.0      0.0
# 1     29    1   2     120.0  243.0  0.0      0.0    160.0    0.0      0.0
# 3     30    0   1     170.0  237.0  0.0      1.0    170.0    0.0      0.0
# 4     31    0   2     100.0  219.0  0.0      1.0    150.0    0.0      0.0
# 5     32    0   2     105.0  198.0  0.0      0.0    165.0    0.0      0.0
# ..   ...  ...  ..       ...    ...  ...      ...      ...    ...      ...
# 289   52    1   4     160.0  331.0  0.0      0.0     94.0    1.0      2.5
# 290   54    0   3     130.0  294.0  0.0      1.0    100.0    1.0      0.0
# 291   56    1   4     155.0  342.0  1.0      0.0    150.0    1.0      3.0
# 292   58    0   2     180.0  393.0  0.0      0.0    110.0    1.0      1.0
# 293   65    1   4     130.0  275.0  0.0      1.0    115.0    1.0      1.0
#
#      num
# 0             0
# 1             0
# 3             0
# 4             0
# ...

# %%
c=data1['restecg'].value_counts()
c
# Out:
# 0.0    208
# 1.0     47
# 2.0      6
# Name: restecg, dtype: int64

# %%
data1=pd.get_dummies(data1,columns=['cp','restecg'])
data1
# Out:
#      age  sex  trestbps   chol  fbs  thalach  exang  oldpeak  num         \
# 0     28    1     130.0  132.0  0.0    185.0    0.0      0.0           0
# 1     29    1     120.0  243.0  0.0    160.0    0.0      0.0           0
# 3     30    0     170.0  237.0  0.0    170.0    0.0      0.0           0
# 4     31    0     100.0  219.0  0.0    150.0    0.0      0.0           0
# 5     32    0     105.0  198.0  0.0    165.0    0.0      0.0           0
# ..   ...  ...       ...    ...  ...      ...    ...      ...         ...
# 289   52    1     160.0  331.0  0.0     94.0    1.0      2.5           1
# 290   54    0     130.0  294.0  0.0    100.0    1.0      0.0           1
# 291   56    1     155.0  342.0  1.0    150.0    1.0      3.0           1
# 292   58    0     180.0  393.0  0.0    110.0    1.0      1.0           1
# 293   65    1     130.0  275.0  0.0    115.0    1.0      1.0           1
#
#      cp_1  cp_2  cp_3  cp_4  restecg_0.0  restecg_1.0  restecg_2.0
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6460\417468844.py in <module>
# ----> 1 y=data1.num
#       2 del data1['num']
#       3 x=data1
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5573         ):
#    5574             return self[name]
# -> 5575         return object.__getattribute__(self, name)
#    5576
#    5577     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'num'

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6460\3724777867.py in <module>
# ----> 1 x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)
#
# NameError: name 'y' is not defined

# %%
data1
# Out:
#      age  sex  trestbps   chol  fbs  thalach  exang  oldpeak  num         \
# 0     28    1     130.0  132.0  0.0    185.0    0.0      0.0           0
# 1     29    1     120.0  243.0  0.0    160.0    0.0      0.0           0
# 3     30    0     170.0  237.0  0.0    170.0    0.0      0.0           0
# 4     31    0     100.0  219.0  0.0    150.0    0.0      0.0           0
# 5     32    0     105.0  198.0  0.0    165.0    0.0      0.0           0
# ..   ...  ...       ...    ...  ...      ...    ...      ...         ...
# 289   52    1     160.0  331.0  0.0     94.0    1.0      2.5           1
# 290   54    0     130.0  294.0  0.0    100.0    1.0      0.0           1
# 291   56    1     155.0  342.0  1.0    150.0    1.0      3.0           1
# 292   58    0     180.0  393.0  0.0    110.0    1.0      1.0           1
# 293   65    1     130.0  275.0  0.0    115.0    1.0      1.0           1
#
#      cp_1  cp_2  cp_3  cp_4  restecg_0.0  restecg_1.0  restecg_2.0
# ...

# %%
data2=data1
data2
# Out:
#      age  sex  trestbps   chol  fbs  thalach  exang  oldpeak  num         \
# 0     28    1     130.0  132.0  0.0    185.0    0.0      0.0           0
# 1     29    1     120.0  243.0  0.0    160.0    0.0      0.0           0
# 3     30    0     170.0  237.0  0.0    170.0    0.0      0.0           0
# 4     31    0     100.0  219.0  0.0    150.0    0.0      0.0           0
# 5     32    0     105.0  198.0  0.0    165.0    0.0      0.0           0
# ..   ...  ...       ...    ...  ...      ...    ...      ...         ...
# 289   52    1     160.0  331.0  0.0     94.0    1.0      2.5           1
# 290   54    0     130.0  294.0  0.0    100.0    1.0      0.0           1
# 291   56    1     155.0  342.0  1.0    150.0    1.0      3.0           1
# 292   58    0     180.0  393.0  0.0    110.0    1.0      1.0           1
# 293   65    1     130.0  275.0  0.0    115.0    1.0      1.0           1
#
#      cp_1  cp_2  cp_3  cp_4  restecg_0.0  restecg_1.0  restecg_2.0
# ...

# %%
y=data2['num       ']
x=data2.drop('num       ',axis=1)

# %%
data1.columns
# Out:
# Index(['age', 'sex', 'trestbps', 'chol', 'fbs', 'thalach', 'exang', 'oldpeak',
#        'num       ', 'cp_1', 'cp_2', 'cp_3', 'cp_4', 'restecg_0.0',
#        'restecg_1.0', 'restecg_2.0'],
#       dtype='object')

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
pred=lr.predict(x_train)

# %%
plt.scatter(x_train,y_train[:,1:2])
plt.plot(x_train,lr.predict(x_train))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6460\1506608591.py in <module>
# ----> 1 plt.scatter(x_train,y_train[:,1:2])
#       2 plt.plot(x_train,lr.predict(x_train))
#       3 plt.show()
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#     982             return self._get_values(key)
#     983
# --> 984         return self._get_with(key)
#     985
#     986     def _get_with(self, key):
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in _get_with(self, key)
#     997             )
#     998         elif isinstance(key, tuple):
# --> 999             return self._get_values_tuple(key)
#    1000
#    1001         elif not is_list_like(key):
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in _get_values_tuple(self, key)
#    1032
#    1033         if not isinstance(self.index, MultiIndex):
# ...

# %%
a=lr.score(x_test,y_test)
a
# Out:
# 0.3836188628220406

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import mean_squared_error,accuracy_score

# %%
dt=DecisionTreeClassifier()
dt.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
dtpred=dt.predict(x_test)
a=mean_squared_error(y_test,dtpred)
a
# Out:
# 0.37735849056603776

# %%
from sklearn.ensemble import RandomForestClassifier
rnd=RandomForestClassifier()
rnd.fit(x_train,y_train)
rndpred=rnd.predict(x_test)
a=accuracy_score(y_test,rndpred)
a
# Out:
# 0.7735849056603774

# %%
from svmlearn
