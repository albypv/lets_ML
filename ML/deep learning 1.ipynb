# %%
import sys; sys.path
# Out:
# ['C:\\Users\\pvalb\\Desktop\\python',
#  'C:\\Users\\pvalb\\anaconda3\\python39.zip',
#  'C:\\Users\\pvalb\\anaconda3\\DLLs',
#  'C:\\Users\\pvalb\\anaconda3\\lib',
#  'C:\\Users\\pvalb\\anaconda3',
#  '',
#  'C:\\Users\\pvalb\\anaconda3\\lib\\site-packages',
#  'C:\\Users\\pvalb\\anaconda3\\lib\\site-packages\\win32',
#  'C:\\Users\\pvalb\\anaconda3\\lib\\site-packages\\win32\\lib',
#  'C:\\Users\\pvalb\\anaconda3\\lib\\site-packages\\Pythonwin',
#  'C:\\Users\\pvalb\\anaconda3\\lib\\site-packages\\IPython\\extensions',
#  'C:\\Users\\pvalb\\.ipython']

# %%
pip install tensorflow --ignore-installed --user
# Out:
# ...
#   Using cached tensorflow-2.12.0-cp39-cp39-win_amd64.whl (1.9 kB)
# ...
#   Using cached tensorflow_intel-2.12.0-cp39-cp39-win_amd64.whl (272.8 MB)
# ...
#   Using cached absl_py-1.4.0-py3-none-any.whl (126 kB)
# ...
#   Using cached astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# ...
#   Using cached flatbuffers-23.5.9-py2.py3-none-any.whl (26 kB)
# ...
#   Using cached gast-0.4.0-py3-none-any.whl (9.8 kB)
# ...
#   Using cached google_pasta-0.2.0-py3-none-any.whl (57 kB)
# ...
#   Using cached h5py-3.8.0-cp39-cp39-win_amd64.whl (2.6 MB)
# ...
#   Using cached jax-0.4.10-py3-none-any.whl
# ...
#   Using cached libclang-16.0.0-py2.py3-none-win_amd64.whl (24.4 MB)
# ...
#   Using cached numpy-1.23.5-cp39-cp39-win_amd64.whl (14.7 MB)
# ...
#   Using cached opt_einsum-3.3.0-py3-none-any.whl (65 kB)
# ...
#   Using cached packaging-23.1-py3-none-any.whl (48 kB)
# ...
#   Using cached protobuf-4.23.0-cp39-cp39-win_amd64.whl (422 kB)
# ...
#   Using cached setuptools-67.7.2-py3-none-any.whl (1.1 MB)
# ...
#   Using cached six-1.16.0-py2.py3-none-any.whl (11 kB)
# ...

# %%
from tensorflow.keras import Sequential 
from keras.layers import Dense

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data=np.loadtxt(r"C:\Users\pvalb\Desktop\python\pima-indians-diabetes.csv",delimiter=',')
data
# Out:
# array([[  6.   , 148.   ,  72.   , ...,   0.627,  50.   ,   1.   ],
#        [  1.   ,  85.   ,  66.   , ...,   0.351,  31.   ,   0.   ],
#        [  8.   , 183.   ,  64.   , ...,   0.672,  32.   ,   1.   ],
#        ...,
#        [  5.   , 121.   ,  72.   , ...,   0.245,  30.   ,   0.   ],
#        [  1.   , 126.   ,  60.   , ...,   0.349,  47.   ,   1.   ],
#        [  1.   ,  93.   ,  70.   , ...,   0.315,  23.   ,   0.   ]])

# %%
x=data[:,:8]
y=data[:,8]

# %%
model=Sequential()
model.add(Dense(10,input_dim=8,kernel_initializer='uniform',activation='relu'))
model.add(Dense(8,kernel_initializer='uniform',activation='relu'))
model.add(Dense(1,kernel_initializer='uniform',activation='sigmoid'))
model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])
model.fit(x,y,epochs=20,batch_size=10,verbose=2)
# Out:
# Epoch 1/20
# 77/77 - 1s - loss: 0.6818 - accuracy: 0.6380 - 577ms/epoch - 7ms/step
# Epoch 2/20
# 77/77 - 0s - loss: 0.6583 - accuracy: 0.6536 - 68ms/epoch - 881us/step
# Epoch 3/20
# 77/77 - 0s - loss: 0.6471 - accuracy: 0.6523 - 69ms/epoch - 891us/step
# Epoch 4/20
# 77/77 - 0s - loss: 0.6287 - accuracy: 0.6797 - 56ms/epoch - 733us/step
# Epoch 5/20
# 77/77 - 0s - loss: 0.6156 - accuracy: 0.6810 - 53ms/epoch - 690us/step
# Epoch 6/20
# 77/77 - 0s - loss: 0.6080 - accuracy: 0.6810 - 55ms/epoch - 712us/step
# Epoch 7/20
# 77/77 - 0s - loss: 0.6032 - accuracy: 0.6914 - 57ms/epoch - 738us/step
# Epoch 8/20
# 77/77 - 0s - loss: 0.5958 - accuracy: 0.6810 - 63ms/epoch - 822us/step
# Epoch 9/20
# 77/77 - 0s - loss: 0.5957 - accuracy: 0.6849 - 63ms/epoch - 816us/step
# Epoch 10/20
# 77/77 - 0s - loss: 0.5928 - accuracy: 0.6836 - 62ms/epoch - 803us/step
# Epoch 11/20
# 77/77 - 0s - loss: 0.5885 - accuracy: 0.6940 - 68ms/epoch - 881us/step
# Epoch 12/20
# ...

# %% [markdown]
# # Example 2

# %%
from keras.datasets import cifar10
from keras.models import Model
from keras.layers import Input,Convolution2D, MaxPooling2D, Dense, Dropout, Activation, Flatten
from keras.utils import np_utils
import numpy as np

# %%
batch_size=32
num_epoch=2
kernel_size=3
pool_size=2
conv_depth_1=32
conv_depth_2=64
drop_prob_1=0.25
drop_pron_2=0.5
hidden_size=512

# %%
(x_train,y_train),(x_test,y_test)=cifar10.load_data()
# Out:
# ...
# 170498071/170498071 [==============================] - 269s 2us/step

# %%
x_train
# Out:
# array([[[[ 59,  62,  63],
#          [ 43,  46,  45],
#          [ 50,  48,  43],
#          ...,
#          [158, 132, 108],
#          [152, 125, 102],
#          [148, 124, 103]],
#
#         [[ 16,  20,  20],
#          [  0,   0,   0],
#          [ 18,   8,   0],
#          ...,
#          [123,  88,  55],
#          [119,  83,  50],
#          [122,  87,  57]],
#
#         [[ 25,  24,  21],
#          [ 16,   7,   0],
#          [ 49,  27,   8],
#          ...,
#          [118,  84,  50],
#          [120,  84,  50],
#          [109,  73,  42]],
#
#         ...,
#
#         [[208, 170,  96],
#          [201, 153,  34],
#          [198, 161,  26],
#          ...,
#          [160, 133,  70],
#          [ 56,  31,   7],
#          [ 53,  34,  20]],
#
#         [[180, 139,  96],
#          [173, 123,  42],
#          [186, 144,  30],
#          ...,
#          [184, 148,  94],
#          [ 97,  62,  34],
#          [ 83,  53,  34]],
#
#         [[177, 144, 116],
# ...

# %%
mun_train,depth,height,width=x_train.shape
num_test=x_test.shape[0]
num_classes=np.unique(y_train).shape[0]

x_train=x_train.astype("float32")
x_test=x_test.astype("float32")
x_train/=np.max(x_train)
x_test/=np.max(x_train)

y_train=np_utils.to_categorical(y_train,num_classes)
y_test=np_utils.to_categorical(y_test,num_classes)

inp=Input(shape=(depth,height,width))

conv_1=Convolution2D(conv_depth_1,kernel_size,kernel_size,padding='same',activation='relu')(inp)
conv_2=Convolution2D(conv_depth_1,kernel_size,kernel_size,padding='same',activation='relu')(conv_1)
pool_1=MaxPooling2D(pool_size=(pool_size,pool_size))(conv_2)
drop_1=Dropout(drop_prob_1)(pool_1)

conv_3=Convolution2D(conv_depth_2,kernel_size,kernel_size,padding='same',activation='relu')(drop_1)
conv_4=Convolution2D(conv_depth_2,kernel_size,kernel_size,padding='same',activation='relu')(conv_3)
pool_2=MaxPooling2D(pool_size=(pool_size,pool_size))(conv_4)
drop_2=Dropout(drop_prob_1)(pool_2)

flat=flatten()(drop_2)
hidden=Dense(hidden_size,activation='relu')(flat)
drop_3=Dropout(drop_prob_2)(hidden)
out=Dense(num_classes,activation='softmax')(drop_3)
 
model=Model(input=inp,output=out)

model.compile(loss='categorical_crossentropy',optimizer='adam',metrics=['accuracy'])
model.fit(x_train,y_train,batch_size=batch_size,epoch=num_epochs,verbose=1,validation_split=0.1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_17172\3504151493.py in <module>
#      20 conv_3=Convolution2D(conv_depth_2,kernel_size,kernel_size,padding='same',activation='relu')(drop_1)
#      21 conv_4=Convolution2D(conv_depth_2,kernel_size,kernel_size,padding='same',activation='relu')(conv_3)
# ---> 22 pool_2=MaxPooling2D(pool_size=(pool_size,pool_size))(conv_4)
#      23 drop_2=Dropout(drop_prob_1)(pool_2)
#      24
#
# ~\AppData\Roaming\Python\Python39\site-packages\keras\utils\traceback_utils.py in error_handler(*args, **kwargs)
#      68             # To get the full stack trace, call:
#      69             # `tf.debugging.disable_traceback_filtering()`
# ---> 70             raise e.with_traceback(filtered_tb) from None
#      71         finally:
#      72             del filtered_tb
#
# ...

# %% [markdown]
# # example 3
